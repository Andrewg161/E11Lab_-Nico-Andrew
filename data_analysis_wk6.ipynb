# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
outside_data = pd.read_csv('wk5_outside_data.csv')
outside_data
# Out:
#              Time  Temperature (C)  Humidity (%)  Pressure (hPa)  Gas (Ohm)  \
# 0    1.740783e+09        24.194453     46.025344     1001.598460       5665
# 1    1.740783e+09        24.426094     46.059154     1001.631455      10310
# 2    1.740783e+09        24.361250     45.849803     1001.643224      14351
# 3    1.740783e+09        24.306758     45.684661     1001.658295      19051
# 4    1.740783e+09        24.267891     45.521555     1001.676775      23994
# ..            ...              ...           ...             ...        ...
# 340  1.740784e+09        24.273555     42.305323     1000.603815     162938
# 341  1.740784e+09        24.284102     42.342375     1000.609168     163894
# 342  1.740784e+09        24.296211     42.355689     1000.611930     162149
# 343  1.740784e+09        24.310859     42.399195     1000.608543     163096
# 344  1.740784e+09        24.324531     42.454572     1000.612161     162938
#
#      PM10  PM2.5  PM100
# 0       8     11     11
# ...

# %%
restroom_data = pd.read_csv('wk5_restroom_data.csv')
restroom_data
# Out:
#              Time  Temperature (C)  Humidity (%)  Pressure (hPa)  Gas (Ohm)  \
# 0    1.740785e+09        24.730586     47.557616     1001.431051      39248
# 1    1.740785e+09        25.013398     47.592472     1001.435815      50934
# 2    1.740785e+09        24.920039     47.223419     1001.461074      55307
# 3    1.740785e+09        24.819063     46.964943     1001.468530      60941
# 4    1.740785e+09        24.739766     46.764814     1001.478983      66139
# ..            ...              ...           ...             ...        ...
# 325  1.740785e+09        23.702461     45.985048     1000.900608     173755
# 326  1.740785e+09        23.702070     46.009422     1000.899962     175026
# 327  1.740785e+09        23.701875     46.009399     1000.899640     174479
# 328  1.740785e+09        23.700898     46.003177     1000.892860     174479
# 329  1.740785e+09        23.702070     46.015528     1000.893075     173216
#
#      PM10  PM2.5  PM100
# 0       7     11     12
# ...

# %%
#temp
plt.plot(restroom_data["Temperature (C)"].iloc[1:300], label="Restroom Data")
plt.plot(outside_data["Temperature (C)"].iloc[1:300], label="Outside Data", color="pink")
plt.ylabel('Temperature (C)')  
plt.xlabel('Time (s)')  
plt.title("Time Series")  
plt.legend()
plt.show()

print("Average inside temp (C):",np.mean(restroom_data["Temperature (C)"].iloc[1:300]))
print("Average outside temp (C):",np.mean(outside_data["Temperature (C)"].iloc[1:300]))
print("STD inside temp (C):",np.std(restroom_data["Temperature (C)"].iloc[1:300]))
print("STD outside temp (C):",np.std(outside_data["Temperature (C)"].iloc[1:300]))
print("Mean Uncertainty inside temp (C):",(np.std(restroom_data["Temperature (C)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty inside temp (C):",(np.std(outside_data["Temperature (C)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average inside temp (C): 23.902528219063544
# Average outside temp (C): 23.972576818561873
# STD inside temp (C): 0.3244136296129705
# STD outside temp (C): 0.7841322442192721
# Mean Uncertainty inside temp (C): 0.01876132461385461
# Mean Uncertainty inside temp (C): 0.04534753854682036

# %%
#humidity
plt.plot(restroom_data["Humidity (%)"].iloc[1:300], label="Restroom Data")
plt.plot(outside_data["Humidity (%)"].iloc[1:300], label="Outside Data", color="pink")
plt.ylabel('Humidity (%)')  
plt.xlabel('Time (s)')  
plt.title("Time Series")  
plt.legend()
plt.show()

print("Average restroom humidity (%):",np.mean(restroom_data["Humidity (%)"].iloc[1:300]))
print("Average outside humidity (%):",np.mean(outside_data["Humidity (%)"].iloc[1:300]))
print("STD restroom humidity (%):",np.std(restroom_data["Humidity (%)"].iloc[1:300]))
print("STD outside humidity (%):",np.std(outside_data["Humidity (%)"].iloc[1:300]))
print("Mean Uncertainty restroom humidity (%):",(np.std(restroom_data["Humidity (%)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside humidity (%):",(np.std(outside_data["Humidity (%)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom humidity (%): 45.89693834939588
# Average outside humidity (%): 43.03976036466326
# STD restroom humidity (%): 0.838039529477814
# STD outside humidity (%): 1.4994398860207097
# Mean Uncertainty restroom humidity (%): 0.0484650773474982
# Mean Uncertainty outside humidity (%): 0.08671484756715338

# %%
#pressure 
plt.plot(restroom_data["Pressure (hPa)"].iloc[1:300], label="Restroom Data")
plt.plot(outside_data["Pressure (hPa)"].iloc[1:300], label="Outside Data", color="pink")
plt.ylabel('Pressure (hPa)')  
plt.xlabel('Time (s)')  
plt.title("Time Series")  
plt.legend()
plt.show()

print("Average restroom pressure (hPa):",np.mean(restroom_data["Pressure (hPa)"].iloc[1:300]))
print("Average outside pressure (hPa):",np.mean(outside_data["Pressure (hPa)"].iloc[1:300]))
print("STD restroom pressure (hPa):",np.std(restroom_data["Pressure (hPa)"].iloc[1:300]))
print("STD outside pressure (hPa):",np.std(outside_data["Pressure (hPa)"].iloc[1:300]))
print("Mean Uncertainty restroom Pressure (hPa):",(np.std(restroom_data["Pressure (hPa)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside Pressure (hPa):",(np.std(outside_data["Pressure (hPa)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom pressure (hPa): 1001.0135138611131
# Average outside pressure (hPa): 1001.0476287805681
# STD restroom pressure (hPa): 0.19314869361117373
# STD outside pressure (hPa): 0.3233676150134457
# Mean Uncertainty restroom Pressure (hPa): 0.011170077360511411
# Mean Uncertainty outside Pressure (hPa): 0.01870083202765862

# %%
#Gas (Ohm)
plt.plot(restroom_data["Gas (Ohm)"].iloc[1:300], label="Restroom Data")
plt.plot(outside_data["Gas (Ohm)"].iloc[1:300], label="Outside Data", color="pink")
plt.ylabel('Gas (Ohm)')  
plt.xlabel('Time (s)')  
plt.title("Time Series")  
plt.legend()
plt.show()


print("Average restroom gas (Ohm):",np.mean(restroom_data["Gas (Ohm)"].iloc[1:300]))
print("Average outside gas (Ohm):",np.mean(outside_data["Gas (Ohm)"].iloc[1:300]))
print("STD restroom gas (Ohm):",np.std(restroom_data["Gas (Ohm)"].iloc[1:300]))
print("STD outside gas (Ohm):",np.std(outside_data["Gas (Ohm)"].iloc[1:300]))
print("Mean Uncertainty restroom Gas (Ohm):",(np.std(restroom_data["Gas (Ohm)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside Gas (Ohm):",(np.std(outside_data["Gas (Ohm)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom gas (Ohm): 157438.0568561873
# Average outside gas (Ohm): 143406.5016722408
# STD restroom gas (Ohm): 23219.3627620793
# STD outside gas (Ohm): 32445.12765585169
# Mean Uncertainty restroom Gas (Ohm): 1342.8104196051343
# Mean Uncertainty outside Gas (Ohm): 1876.350179292985

# %%
#PM10
plt.plot(restroom_data["PM10"].iloc[1:300], label="Restroom Data")
plt.plot(outside_data["PM10"].iloc[1:300], label="Outside Data", color="pink")
plt.ylabel('PM10')  
plt.xlabel('Time (s)')  
plt.title("Time Series")  
plt.legend()
plt.show()


print("Average restroom PM10:",np.mean(restroom_data["PM10"].iloc[1:300]))
print("Average outside PM10:",np.mean(outside_data["PM10"].iloc[1:300]))
print("STD restroom PM10:",np.std(restroom_data["PM10"].iloc[1:300]))
print("STD outside PM10:",np.std(outside_data["PM10"].iloc[1:300]))
print("Mean Uncertainty restroom PM10:",(np.std(restroom_data["PM10"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside PM10:",(np.std(outside_data["PM10"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom PM10: 2.347826086956522
# Average outside PM10: 11.896321070234114
# STD restroom PM10: 2.3871353138319478
# STD outside PM10: 2.948717737975559
# Mean Uncertainty restroom PM10: 0.13805159966129324
# Mean Uncertainty outside PM10: 0.17052874980249813

# %%
#PM2.5
plt.plot(restroom_data["PM2.5"].iloc[1:300], label="Restroom Data")
plt.plot(outside_data["PM2.5"].iloc[1:300], label="Outside Data", color="pink")
plt.ylabel('PM2.5')  
plt.xlabel('Time (s)')  
plt.title("Time Series")  
plt.legend()
plt.show()


print("Average restroom PM2.5:",np.mean(restroom_data["PM2.5"].iloc[1:300]))
print("Average outside PM2.5:",np.mean(outside_data["PM2.5"].iloc[1:300]))
print("STD restroom PM2.5:",np.std(restroom_data["PM2.5"].iloc[1:300]))
print("STD outside PM2.5:",np.std(outside_data["PM2.5"].iloc[1:300]))
print("Mean Uncertainty restroom PM2.5:",(np.std(restroom_data["PM2.5"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside PM2.5:",(np.std(outside_data["PM2.5"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom PM2.5: 3.648829431438127
# Average outside PM2.5: 18.304347826086957
# STD restroom PM2.5: 3.4786145948257126
# STD outside PM2.5: 5.517774364652625
# Mean Uncertainty restroom PM2.5: 0.20117347627434023
# Mean Uncertainty outside PM2.5: 0.3191011306299147

# %%
#PM100
plt.plot(restroom_data["PM100"].iloc[1:300], label="Restroom Data")
plt.plot(outside_data["PM100"].iloc[1:300], label="Outside Data", color="pink")
plt.ylabel('PM100')  
plt.xlabel('Time (s)')  
plt.title("Time Series")  
plt.legend()
plt.show()

print("Average restroom PM100:",np.mean(restroom_data["PM100"].iloc[1:300]))
print("Average outside PM100:",np.mean(outside_data["PM100"].iloc[1:300]))
print("STD restroom PM100:",np.std(restroom_data["PM100"].iloc[1:300]))
print("STD outside PM100:",np.std(outside_data["PM100"].iloc[1:300]))
print("Mean Uncertainty restroom PM100:",(np.std(restroom_data["PM100"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside PM100:",(np.std(outside_data["PM100"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom PM100: 4.133779264214047
# Average outside PM100: 20.08361204013378
# STD restroom PM100: 3.7731000133143886
# STD outside PM100: 6.458747328507326
# Mean Uncertainty restroom PM100: 0.21820400775017307
# Mean Uncertainty outside PM100: 0.373519002187285

# %%
#HISTOGRAM

# %%
#temp
plt.hist(restroom_data["Temperature (C)"].iloc[1:300], bins=8, label="Restroom Data")
plt.hist(outside_data["Temperature (C)"].iloc[1:300], bins=8, label="Outside Data", color="pink", alpha=0.9) 
plt.xlabel('Temperature (C)')
plt.ylabel('Frequency')  
plt.title("Histogram")
plt.legend()
plt.show()

outside_mean = np.mean(outside_data["Temperature (C)"].iloc[1:300])
std_outside = np.std(outside_data["Temperature (C)"].iloc[1:300])
x = np.linspace(min(outside_data["Temperature (C)"].iloc[1:300]), max(outside_data["Temperature (C)"].iloc[1:300]))
y = norm.pdf(x, outside_mean, std_outside)
plt.plot(x, y, label="Normal Distribution Outside")
restroom_mean = np.mean(restroom_data["Temperature (C)"].iloc[1:300])
std_restroom = np.std(restroom_data["Temperature (C)"].iloc[1:300])
x = np.linspace(min(restroom_data["Temperature (C)"].iloc[1:300]), max(restroom_data["Temperature (C)"].iloc[1:300]))
y = norm.pdf(x, restroom_mean, std_restroom)
plt.plot(x, y, label="Normal Distribution Restroom")
plt.legend()

print("Average restroom temp (C):",np.mean(restroom_data["Temperature (C)"].iloc[1:300]))
print("Average outside temp (C):",np.mean(outside_data["Temperature (C)"].iloc[1:300]))
print("STD restroom temp (C):",np.std(restroom_data["Temperature (C)"].iloc[1:300]))
print("STD outside temp (C):",np.std(outside_data["Temperature (C)"].iloc[1:300]))
print("Mean Uncertainty restroom Temperature (C):",(np.std(restroom_data["Temperature (C)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside Temperature (C):",(np.std(outside_data["Temperature (C)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom temp (C): 23.902528219063544
# Average outside temp (C): 23.972576818561873
# STD restroom temp (C): 0.3244136296129705
# STD outside temp (C): 0.7841322442192721
# Mean Uncertainty restroom Temperature (C): 0.01876132461385461
# Mean Uncertainty outside Temperature (C): 0.04534753854682036

# %%
#Humidity (%)	
plt.hist(restroom_data["Humidity (%)"].iloc[1:300], bins=15, label="Restroom Data")
plt.hist(outside_data["Humidity (%)"].iloc[1:300], bins=15, label="Outside Data", color="pink", alpha=0.9) 
plt.xlabel('Humidity (%)')
plt.ylabel('Frequency')  
plt.title("Histogram")
plt.legend()
plt.show()

outside_mean = np.mean(outside_data["Humidity (%)"].iloc[1:300])
std_outside = np.std(outside_data["Humidity (%)"].iloc[1:300])
x = np.linspace(min(outside_data["Humidity (%)"].iloc[1:300]), max(outside_data["Humidity (%)"].iloc[1:300]))
y = norm.pdf(x, outside_mean, std_outside)
plt.plot(x, y, label="Normal Distribution Outside")
restroom_mean = np.mean(restroom_data["Humidity (%)"].iloc[1:300])
std_restroom = np.std(restroom_data["Humidity (%)"].iloc[1:300])
x = np.linspace(min(restroom_data["Humidity (%)"].iloc[1:300]), max(restroom_data["Humidity (%)"].iloc[1:300]))
y = norm.pdf(x, restroom_mean, std_restroom)
plt.plot(x, y, label="Normal Distribution Restroom")
plt.legend()

print("Average restroom humidity (%):",np.mean(restroom_data["Humidity (%)"].iloc[1:300]))
print("Average outside humidity (%):",np.mean(outside_data["Humidity (%)"].iloc[1:300]))
print("STD restroom humidity (%):",np.std(restroom_data["Humidity (%)"].iloc[1:300]))
print("STD outside humidity (%):",np.std(outside_data["Humidity (%)"].iloc[1:300]))
print("Mean Uncertainty restroom Humidity (%):",(np.std(restroom_data["Humidity (%)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside Humidity (%):",(np.std(outside_data["Humidity (%)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom humidity (%): 45.89693834939588
# Average outside humidity (%): 43.03976036466326
# STD restroom humidity (%): 0.838039529477814
# STD outside humidity (%): 1.4994398860207097
# Mean Uncertainty restroom Humidity (%): 0.0484650773474982
# Mean Uncertainty outside Humidity (%): 0.08671484756715338

# %%
#Pressure (hPa)
plt.hist(restroom_data["Pressure (hPa)"].iloc[1:300], bins=15, label="Restroom Data")
plt.hist(outside_data["Pressure (hPa)"].iloc[1:300], bins=15, label="Outside Data", color="pink", alpha=0.9)
plt.xlabel('Pressure (hPa)')
plt.ylabel('Frequency')  
plt.title("Histogram")
plt.legend()
plt.show()

outside_mean = np.mean(outside_data["Pressure (hPa)"].iloc[1:300])
std_outside = np.std(outside_data["Pressure (hPa)"].iloc[1:300])
x = np.linspace(min(outside_data["Pressure (hPa)"].iloc[1:300]), max(outside_data["Pressure (hPa)"].iloc[1:300]))
y = norm.pdf(x, outside_mean, std_outside)
plt.plot(x, y, label="Normal Distribution Outside")
restroom_mean = np.mean(restroom_data["Pressure (hPa)"].iloc[1:300])
std_restroom = np.std(restroom_data["Pressure (hPa)"].iloc[1:300])
x = np.linspace(min(restroom_data["Pressure (hPa)"].iloc[1:300]), max(restroom_data["Pressure (hPa)"].iloc[1:300]))
y = norm.pdf(x, restroom_mean, std_restroom)
plt.plot(x, y, label="Normal Distribution Restroom")
plt.legend()

print("Average restroom pressure (hPa):",np.mean(restroom_data["Pressure (hPa)"].iloc[1:300]))
print("Average outside pressure (hPa):",np.mean(outside_data["Pressure (hPa)"].iloc[1:300]))
print("STD restroom pressure (hPa):",np.std(restroom_data["Pressure (hPa)"].iloc[1:300]))
print("STD outside pressure (hPa):",np.std(outside_data["Pressure (hPa)"].iloc[1:300]))
print("Mean Uncertainty restroom Pressure (hPa):",(np.std(restroom_data["Pressure (hPa)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside Pressure (hPa):",(np.std(outside_data["Pressure (hPa)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom pressure (hPa): 1001.0135138611131
# Average outside pressure (hPa): 1001.0476287805681
# STD restroom pressure (hPa): 0.19314869361117373
# STD outside pressure (hPa): 0.3233676150134457
# Mean Uncertainty restroom Pressure (hPa): 0.011170077360511411
# Mean Uncertainty outside Pressure (hPa): 0.01870083202765862

# %%
#Gas (Ohm)
plt.hist(restroom_data["Gas (Ohm)"].iloc[1:300], bins=10, label="Restroom Data")
plt.hist(outside_data["Gas (Ohm)"].iloc[1:300], bins=10, label="Outside Data", color="pink", alpha=0.9)
plt.xlabel('Gas (Ohm)')
plt.ylabel('Frequency')  
plt.title("Histogram")
plt.legend()
plt.show()

outside_mean = np.mean(outside_data["Gas (Ohm)"].iloc[1:300])
std_outside = np.std(outside_data["Gas (Ohm)"].iloc[1:300])
x = np.linspace(min(outside_data["Gas (Ohm)"].iloc[1:300]), max(outside_data["Gas (Ohm)"].iloc[1:300]))
y = norm.pdf(x, outside_mean, std_outside)
plt.plot(x, y, label="Normal Distribution Outside")
restroom_mean = np.mean(restroom_data["Gas (Ohm)"].iloc[1:300])
std_restroom = np.std(restroom_data["Gas (Ohm)"].iloc[1:300])
x = np.linspace(min(restroom_data["Gas (Ohm)"].iloc[1:300]), max(restroom_data["Gas (Ohm)"].iloc[1:300]))
y = norm.pdf(x, restroom_mean, std_restroom)
plt.plot(x, y, label="Normal Distribution Restroom")
plt.legend()

print("Average restroom gas (Ohm):",np.mean(restroom_data["Gas (Ohm)"].iloc[1:300]))
print("Average outside gas (Ohm):",np.mean(outside_data["Gas (Ohm)"].iloc[1:300]))
print("STD restroom gas (Ohm):",np.std(restroom_data["Gas (Ohm)"].iloc[1:300]))
print("STD outside gas (Ohm):",np.std(outside_data["Gas (Ohm)"].iloc[1:300]))
print("Mean Uncertainty restroom Gas (Ohm):",(np.std(restroom_data["Gas (Ohm)"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside Gas (Ohm):",(np.std(outside_data["Gas (Ohm)"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom gas (Ohm): 157438.0568561873
# Average outside gas (Ohm): 143406.5016722408
# STD restroom gas (Ohm): 23219.3627620793
# STD outside gas (Ohm): 32445.12765585169
# Mean Uncertainty restroom Gas (Ohm): 1342.8104196051343
# Mean Uncertainty outside Gas (Ohm): 1876.350179292985

# %%
#PM10
plt.hist(restroom_data["PM10"].iloc[1:300], bins=7, label="Restroom Data")
plt.hist(outside_data["PM10"].iloc[1:300], bins=7, label="Outside Data", color="pink", alpha=0.9)
plt.xlabel('PM10')
plt.ylabel('Frequency')  
plt.title("Histogram")
plt.legend()
plt.show()

outside_mean = np.mean(outside_data["PM10"].iloc[1:300])
std_outside = np.std(outside_data["PM10"].iloc[1:300])
x = np.linspace(min(outside_data["PM10"].iloc[1:300]), max(outside_data["PM10"].iloc[1:300]))
y = norm.pdf(x, outside_mean, std_outside)
plt.plot(x, y, label="Normal Distribution Outside")
restroom_mean = np.mean(restroom_data["PM10"].iloc[1:300])
std_restroom = np.std(restroom_data["PM10"].iloc[1:300])
x = np.linspace(min(restroom_data["PM10"].iloc[1:300]), max(restroom_data["PM10"].iloc[1:300]))
y = norm.pdf(x, restroom_mean, std_restroom)
plt.plot(x, y, label="Normal Distribution Restroom")
plt.legend()

print("Average restroom PM10:",np.mean(restroom_data["PM10"].iloc[1:300]))
print("Average outside PM10:",np.mean(outside_data["PM10"].iloc[1:300]))
print("STD restroom PM10:",np.std(restroom_data["PM10"].iloc[1:300]))
print("STD outside PM10:",np.std(outside_data["PM10"].iloc[1:300]))
print("Mean Uncertainty restroom PM10:",(np.std(restroom_data["PM10"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside PM10:",(np.std(outside_data["PM10"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom PM10: 2.347826086956522
# Average outside PM10: 11.896321070234114
# STD restroom PM10: 2.3871353138319478
# STD outside PM10: 2.948717737975559
# Mean Uncertainty restroom PM10: 0.13805159966129324
# Mean Uncertainty outside PM10: 0.17052874980249813

# %%
#PM2.5
plt.hist(restroom_data["PM2.5"].iloc[1:300], bins=8, label="Restroom Data")
plt.hist(outside_data["PM2.5"].iloc[1:300], bins=8, label="Outside Data", color="pink", alpha=0.9)
plt.xlabel('PM2.5')
plt.ylabel('Frequency')  
plt.title("Histogram")
plt.legend()
plt.show()

outside_mean = np.mean(outside_data["PM2.5"].iloc[1:300])
std_outside = np.std(outside_data["PM2.5"].iloc[1:300])
x = np.linspace(min(outside_data["PM2.5"].iloc[1:300]), max(outside_data["PM2.5"].iloc[1:300]))
y = norm.pdf(x, outside_mean, std_outside)
plt.plot(x, y, label="Normal Distribution Outside")
restroom_mean = np.mean(restroom_data["PM2.5"].iloc[1:300])
std_restroom = np.std(restroom_data["PM2.5"].iloc[1:300])
x = np.linspace(min(restroom_data["PM2.5"].iloc[1:300]), max(restroom_data["PM2.5"].iloc[1:300]))
y = norm.pdf(x, restroom_mean, std_restroom)
plt.plot(x, y, label="Normal Distribution Restroom")
plt.legend()

print("Average restroom PM2.5:",np.mean(restroom_data["PM2.5"].iloc[1:300]))
print("Average outside PM2.5:",np.mean(outside_data["PM2.5"].iloc[1:300]))
print("STD restroom PM2.5:",np.std(restroom_data["PM2.5"].iloc[1:300]))
print("STD outside PM2.5:",np.std(outside_data["PM2.5"].iloc[1:300]))
print("Mean Uncertainty restroom PM2.5:",(np.std(restroom_data["PM2.5"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom PM2.5: 3.648829431438127
# Average outside PM2.5: 18.304347826086957
# STD restroom PM2.5: 3.4786145948257126
# STD outside PM2.5: 5.517774364652625
# Mean Uncertainty restroom PM2.5: 0.20117347627434023

# %%
#PM100
plt.hist(restroom_data["PM100"].iloc[1:300], bins=8, label="Restroom Data")
plt.hist(outside_data["PM100"].iloc[1:300], bins=8, label="Outside Data", color="pink", alpha=0.9)
plt.xlabel('PM100')
plt.ylabel('Frequency')  
plt.title("Histogram")
plt.legend()
plt.show()

outside_mean = np.mean(outside_data["PM100"].iloc[1:300])
std_outside = np.std(outside_data["PM100"].iloc[1:300])
x = np.linspace(min(outside_data["PM100"].iloc[1:300]), max(outside_data["PM100"].iloc[1:300]))
y = norm.pdf(x, outside_mean, std_outside)
plt.plot(x, y, label="Normal Distribution Outside")
restroom_mean = np.mean(restroom_data["PM100"].iloc[1:300])
std_restroom = np.std(restroom_data["PM100"].iloc[1:300])
x = np.linspace(min(restroom_data["PM100"].iloc[1:300]), max(restroom_data["PM100"].iloc[1:300]))
y = norm.pdf(x, restroom_mean, std_restroom)
plt.plot(x, y, label="Normal Distribution Restroom")
plt.legend()

print("Average restroom PM100:",np.mean(restroom_data["PM100"].iloc[1:300]))
print("Average outside PM100:",np.mean(outside_data["PM100"].iloc[1:300]))
print("STD restroom PM100:",np.std(restroom_data["PM100"].iloc[1:300]))
print("STD outside PM100:",np.std(outside_data["PM100"].iloc[1:300]))
print("Mean Uncertainty restroom PM100:",(np.std(restroom_data["PM100"].iloc[1:300]))/np.sqrt(299))
print("Mean Uncertainty outside PM100:",(np.std(outside_data["PM100"].iloc[1:300]))/np.sqrt(299))
# Out:
# Average restroom PM100: 4.133779264214047
# Average outside PM100: 20.08361204013378
# STD restroom PM100: 3.7731000133143886
# STD outside PM100: 6.458747328507326
# Mean Uncertainty restroom PM100: 0.21820400775017307
# Mean Uncertainty outside PM100: 0.373519002187285

# %%
#Temp vs Humidity 
plt.plot(outside_data["Humidity (%)"].iloc[1:300], outside_data["Temperature (C)"].iloc[1:300])
plt.ylabel('Temperature (C)')  
plt.xlabel('Humidity (%)')  
plt.title("Temperature vs Humidity")
# Out:
# Text(0.5, 1.0, 'Temperature vs Humidity')

# %%
#Temp vs PM2.5 
plt.plot(outside_data["PM2.5"].iloc[1:300], outside_data["Temperature (C)"].iloc[1:300])
plt.ylabel('Temperature (C)')  
plt.xlabel('PM2.5')  
plt.title("Temperature vs PM2.5")
# Out:
# Text(0.5, 1.0, 'Temperature vs PM2.5')

# %%
#Temp vs Pressure 
plt.plot(outside_data["Pressure (hPa)"].iloc[1:300], outside_data["Temperature (C)"].iloc[1:300])
plt.ylabel('Temperature (C)')  
plt.xlabel('Pressure (hPa)')  
plt.title("Temperature vs Pressure")
# Out:
# Text(0.5, 1.0, 'Temperature vs Pressure')
